# %%
# !pip install pymysql

# %%
import pymysql

# %%
dbcon=pymysql.connect(host='localhost',user='root',password='Ming@1999',database='google')

# %%
dbcon

# %%
import pandas as pd

# %%
df= pd.read_sql_query("select * from employee2",con=dbcon)
# Out:
# C:\Users\Munna kumar\AppData\Local\Temp\ipykernel_9876\1007853323.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql_query("select * from employee2",con=dbcon)

# %%
df
# Out:
#     emp_ID     emp_NAME DEPT_NAME  SALARY
# 0      101  Mohan Singh     Admin    4000
# 1      102     Rajkumar        HR    3000
# 2      103        Akbar        IT    4000
# 3      104       Dorvin   Finance    6500
# 4      105        Rohit        HR    3000
# 5      106       Rajesh   Finance    5000
# 6      107        Preet        HR    7000
# 7      108       Maryam     Admin    4000
# 8      109       Sanjay        IT    6500
# 9      110      Vasudha        IT    7000
# 10     111      Melinda        IT    8000
# 11     112        Komal        IT   10000
# 12     113      Gautham     Admin    2000
# 13     114      Manisha        HR    3000
# 14     115      Chandni        IT    4500
# 15     116        Satya   Finance    6500
# 16     117       Adarsh        HR    3500
# 17     118      Tejaswi   Finance    5500
# 18     119         Cory        HR    8000
# 19     120       Monica     Admin    5000
# 20     121      Rosalin        IT    6000
# ...

# %%
df[df['emp_ID']==102][['emp_NAME','SALARY']]
# Out:
#    emp_NAME  SALARY
# 1  Rajkumar    3000

# %%
df1 = pd.read_sql_query("select * from employee2 where salary>4000",con=dbcon)
# Out:
# C:\Users\Munna kumar\AppData\Local\Temp\ipykernel_9876\3865760341.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql_query("select * from employee2 where salary>4000",con=dbcon)

# %%
df1
# Out:
#     emp_ID emp_NAME DEPT_NAME  SALARY
# 0      104   Dorvin   Finance    6500
# 1      106   Rajesh   Finance    5000
# 2      107    Preet        HR    7000
# 3      109   Sanjay        IT    6500
# 4      110  Vasudha        IT    7000
# 5      111  Melinda        IT    8000
# 6      112    Komal        IT   10000
# 7      115  Chandni        IT    4500
# 8      116    Satya   Finance    6500
# 9      118  Tejaswi   Finance    5500
# 10     119     Cory        HR    8000
# 11     120   Monica     Admin    5000
# 12     121  Rosalin        IT    6000
# 13     122  Ibrahim        IT    8000
# 14     123   Vikram        IT    8000
# 15     124  Dheeraj        IT   11000
# 16     125    Vicky     Admin    5000
# 17     129    Preet        HR    7000
# 18     130   Kushal        IT    5000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   emp_ID     19 non-null     int64
#  1   emp_NAME   19 non-null     object
#  2   DEPT_NAME  19 non-null     object
#  3   SALARY     19 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 740.0+ bytes

# %%
df1.shape
# Out:
# (19, 4)

# %%
df1.describe()
# Out:
#            emp_ID        SALARY
# count   19.000000     19.000000
# mean   116.894737   6815.789474
# std      7.766701   1741.730671
# min    104.000000   4500.000000
# 25%    110.500000   5250.000000
# 50%    118.000000   6500.000000
# 75%    122.500000   8000.000000
# max    130.000000  11000.000000

# %%
df1.describe(include='all')
# Out:
#             emp_ID emp_NAME DEPT_NAME        SALARY
# count    19.000000       19        19     19.000000
# unique         NaN       18         4           NaN
# top            NaN    Preet        IT           NaN
# freq           NaN        2        10           NaN
# mean    116.894737      NaN       NaN   6815.789474
# std       7.766701      NaN       NaN   1741.730671
# min     104.000000      NaN       NaN   4500.000000
# 25%     110.500000      NaN       NaN   5250.000000
# 50%     118.000000      NaN       NaN   6500.000000
# 75%     122.500000      NaN       NaN   8000.000000
# max     130.000000      NaN       NaN  11000.000000

# %%
# new connection

# %%
dbcon1 = pymysql.connect(host='localhost',user='root',password='Ming@1999',database='company1')

# %%
dbcon1

# %%
df_dept = pd.read_sql_query("select * from department",con=dbcon1)
# Out:
# C:\Users\Munna kumar\AppData\Local\Temp\ipykernel_9876\212862779.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_dept = pd.read_sql_query("select * from department",con=dbcon1)

# %%
df_dept
# Out:
#    Dep_id     dep_name
# 0       1    Executive
# 1       2           HR
# 2       3        Sales
# 3       4  Development
# 4       5      Support
# 5       6     Research

# %%
df_emp = pd.read_sql_query("select * from employee",con=dbcon1)
# Out:
# C:\Users\Munna kumar\AppData\Local\Temp\ipykernel_9876\3392412192.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_emp = pd.read_sql_query("select * from employee",con=dbcon1)

# %%
df_emp
# Out:
#     employee_id             full_name  Dep_id             job_role   Id
# 0          1001            John Smith       1                  CEO  101
# 1          1002          Sarah Goodes       1                  CFO  101
# 2          1003          Wayne Ablett       1                  CIO  101
# 3          1004        Michelle Carey       2           HR Manager  102
# 4          1005        Chris Matthews       3       Sales Manager   103
# 5          1006           Andrew Judd       4  Development Manager  106
# 6          1007       Danielle McLeod       5      Support Manager  104
# 7          1008          Matthew Swan       2    HR Representative  105
# 8          1009  Stephanie Richardson       2          Salesperson  105
# 9          1010            Tony Grant       3          Salesperson  103
# 10         1011         Jenna Lockett       4  Front-End Developer  106
# 11         1012      Michael Dunstall       4   Back-End Developer  106
# ...

# %%
df_inner=df_emp.merge(df_dept,how='inner')

# %%
df_inner
# Out:
#     employee_id             full_name  Dep_id             job_role   Id  \
# 0          1001            John Smith       1                  CEO  101
# 1          1002          Sarah Goodes       1                  CFO  101
# 2          1003          Wayne Ablett       1                  CIO  101
# 3          1004        Michelle Carey       2           HR Manager  102
# 4          1008          Matthew Swan       2    HR Representative  105
# 5          1009  Stephanie Richardson       2          Salesperson  105
# 6          1005        Chris Matthews       3       Sales Manager   103
# 7          1010            Tony Grant       3          Salesperson  103
# 8          1006           Andrew Judd       4  Development Manager  106
# 9          1011         Jenna Lockett       4  Front-End Developer  106
# 10         1012      Michael Dunstall       4   Back-End Developer  106
# 11         1013             Jane Voss       4   Back-End Developer  106
# ...

# %%
df_outer=df_emp.merge(df_dept,how='outer')

# %%
df_outer
# Out:
#     employee_id             full_name  Dep_id             job_role     Id  \
# 0        1001.0            John Smith       1                  CEO  101.0
# 1        1002.0          Sarah Goodes       1                  CFO  101.0
# 2        1003.0          Wayne Ablett       1                  CIO  101.0
# 3        1004.0        Michelle Carey       2           HR Manager  102.0
# 4        1008.0          Matthew Swan       2    HR Representative  105.0
# 5        1009.0  Stephanie Richardson       2          Salesperson  105.0
# 6        1005.0        Chris Matthews       3       Sales Manager   103.0
# 7        1010.0            Tony Grant       3          Salesperson  103.0
# 8        1006.0           Andrew Judd       4  Development Manager  106.0
# 9        1011.0         Jenna Lockett       4  Front-End Developer  106.0
# 10       1012.0      Michael Dunstall       4   Back-End Developer  106.0
# 11       1013.0             Jane Voss       4   Back-End Developer  106.0
# ...
